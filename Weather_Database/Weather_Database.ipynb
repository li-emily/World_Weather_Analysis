# %%
# Create a new set of 2,000 random latitudes and longitudes.

# Get the nearest city using the citipy module.

# Perform an API call with the OpenWeatherMap.

# Retrieve the Following
    # Latitude and longitude
    # Maximum temperature
    # Percent humidity
    # Percent cloudiness
    # Wind speed
    # Weather description (for example, clouds, fog, light rain, clear sky)
    
# Add the data to a new DataFrame
# Export the DataFrame as a CSV file, and save it as WeatherPy_Database.csv in the Weather_Database folder.

# %%
# Import the dependencies.
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt


from citipy import citipy
from config import weather_api_key
import requests

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_desc = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_desc})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | east london
# Processing Record 2 of Set 1 | albany
# Processing Record 3 of Set 1 | mataura
# Processing Record 4 of Set 1 | port elizabeth
# Processing Record 5 of Set 1 | samarai
# Processing Record 6 of Set 1 | lovozero
# Processing Record 7 of Set 1 | kapaa
# Processing Record 8 of Set 1 | kavieng
# Processing Record 9 of Set 1 | lompoc
# Processing Record 10 of Set 1 | boa vista
# Processing Record 11 of Set 1 | khatanga
# Processing Record 12 of Set 1 | athabasca
# Processing Record 13 of Set 1 | rikitea
# Processing Record 14 of Set 1 | provideniya
# Processing Record 15 of Set 1 | marystown
# Processing Record 16 of Set 1 | chuy
# Processing Record 17 of Set 1 | hobart
# Processing Record 18 of Set 1 | vardo
# Processing Record 19 of Set 1 | tuatapere
# Processing Record 20 of Set 1 | babanusah
# City not found. Skipping...
# Processing Record 21 of Set 1 | punta arenas
# Processing Record 22 of Set 1 | marzuq
# Processing Record 23 of Set 1 | ormara
# Processing Record 24 of Set 1 | dumas
# Processing Record 25 of Set 1 | northam
# Processing Record 26 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 27 of Set 1 | morondava
# Processing Record 28 of Set 1 | berdigestyakh
# Processing Record 29 of Set 1 | tawang
# Processing Record 30 of Set 1 | souillac
# Processing Record 31 of Set 1 | tuktoyaktuk
# Processing Record 32 of Set 1 | barbar
# City not found. Skipping...
# Processing Record 33 of Set 1 | butaritari
# Processing Record 34 of Set 1 | georgetown
# Processing Record 35 of Set 1 | los llanos de aridane
# Processing Record 36 of Set 1 | airai
# Processing Record 37 of Set 1 | barrow
# Processing Record 38 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 39 of Set 1 | coihaique
# Processing Record 40 of Set 1 | ambon
# Processing Record 41 of Set 1 | puerto ayora
# Processing Record 42 of Set 1 | tiksi
# Processing Record 43 of Set 1 | stornoway
# Processing Record 44 of Set 1 | broome
# Processing Record 45 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 46 of Set 1 | qaanaaq
# Processing Record 47 of Set 1 | cidreira
# Processing Record 48 of Set 1 | kahului
# Processing Record 49 of Set 1 | tursunzoda
# Processing Record 50 of Set 1 | ommen
# Processing Record 1 of Set 2 | ahipara
# Processing Record 2 of Set 2 | torbay
# Processing Record 3 of Set 2 | busselton
# Processing Record 4 of Set 2 | navalcarnero
# Processing Record 5 of Set 2 | port alfred
# Processing Record 6 of Set 2 | hami
# Processing Record 7 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 8 of Set 2 | malanje
# Processing Record 9 of Set 2 | taoudenni
# Processing Record 10 of Set 2 | noumea
# Processing Record 11 of Set 2 | bolshegrivskoye
# City not found. Skipping...
# Processing Record 12 of Set 2 | upernavik
# Processing Record 13 of Set 2 | avarua
# Processing Record 14 of Set 2 | bambous virieux
# Processing Record 15 of Set 2 | codrington
# Processing Record 16 of Set 2 | hermanus
# Processing Record 17 of Set 2 | culasi
# Processing Record 18 of Set 2 | fairbanks
# Processing Record 19 of Set 2 | hithadhoo
# Processing Record 20 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 21 of Set 2 | lagoa
# Processing Record 22 of Set 2 | yellowknife
# Processing Record 23 of Set 2 | ushuaia
# Processing Record 24 of Set 2 | lorengau
# Processing Record 25 of Set 2 | xushan
# Processing Record 26 of Set 2 | koppang
# Processing Record 27 of Set 2 | kutulik
# Processing Record 28 of Set 2 | boguchany
# Processing Record 29 of Set 2 | vaini
# Processing Record 30 of Set 2 | mae ramat
# Processing Record 31 of Set 2 | hamilton
# Processing Record 32 of Set 2 | kuche
# City not found. Skipping...
# Processing Record 33 of Set 2 | olafsvik
# Processing Record 34 of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record 35 of Set 2 | acapulco
# Processing Record 36 of Set 2 | sabang
# Processing Record 37 of Set 2 | bima
# Processing Record 38 of Set 2 | artyk
# City not found. Skipping...
# Processing Record 39 of Set 2 | dunhua
# Processing Record 40 of Set 2 | chokurdakh
# Processing Record 41 of Set 2 | cape town
# Processing Record 42 of Set 2 | yerbogachen
# Processing Record 43 of Set 2 | bengkulu
# Processing Record 44 of Set 2 | vidim
# Processing Record 45 of Set 2 | atuona
# Processing Record 46 of Set 2 | new norfolk
# Processing Record 47 of Set 2 | bluff
# Processing Record 48 of Set 2 | severo-kurilsk
# Processing Record 49 of Set 2 | wanning
# Processing Record 50 of Set 2 | necochea
# Processing Record 1 of Set 3 | atar
# Processing Record 2 of Set 3 | zelenoborsk
# Processing Record 3 of Set 3 | pringsewu
# Processing Record 4 of Set 3 | faanui
# Processing Record 5 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 6 of Set 3 | araouane
# Processing Record 7 of Set 3 | sept-iles
# Processing Record 8 of Set 3 | san-pedro
# Processing Record 9 of Set 3 | surt
# Processing Record 10 of Set 3 | vao
# Processing Record 11 of Set 3 | port pirie
# Processing Record 12 of Set 3 | arraial do cabo
# Processing Record 13 of Set 3 | hobyo
# Processing Record 14 of Set 3 | rungata
# City not found. Skipping...
# Processing Record 15 of Set 3 | iskateley
# Processing Record 16 of Set 3 | mutsamudu
# City not found. Skipping...
# Processing Record 17 of Set 3 | jamestown
# Processing Record 18 of Set 3 | warqla
# City not found. Skipping...
# Processing Record 19 of Set 3 | kushima
# Processing Record 20 of Set 3 | clyde river
# Processing Record 21 of Set 3 | buluang
# Processing Record 22 of Set 3 | mahebourg
# Processing Record 23 of Set 3 | isangel
# Processing Record 24 of Set 3 | chokwe
# Processing Record 25 of Set 3 | narsaq
# Processing Record 26 of Set 3 | elko
# Processing Record 27 of Set 3 | toro
# Processing Record 28 of Set 3 | sao joao da barra
# Processing Record 29 of Set 3 | saint-philippe
# Processing Record 30 of Set 3 | aksu
# Processing Record 31 of Set 3 | mandera
# Processing Record 32 of Set 3 | nikolskoye
# Processing Record 33 of Set 3 | mattru
# Processing Record 34 of Set 3 | ordynskoye
# Processing Record 35 of Set 3 | grand gaube
# Processing Record 36 of Set 3 | orotukan
# Processing Record 37 of Set 3 | biltine
# Processing Record 38 of Set 3 | skibbereen
# Processing Record 39 of Set 3 | cherskiy
# Processing Record 40 of Set 3 | bethel
# Processing Record 41 of Set 3 | koumac
# Processing Record 42 of Set 3 | pacific grove
# Processing Record 43 of Set 3 | tokur
# Processing Record 44 of Set 3 | majene
# Processing Record 45 of Set 3 | resistencia
# Processing Record 46 of Set 3 | sasykoli
# Processing Record 47 of Set 3 | pauini
# Processing Record 48 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 49 of Set 3 | ruatoria
# City not found. Skipping...
# Processing Record 50 of Set 3 | avera
# Processing Record 1 of Set 4 | stonewall
# Processing Record 2 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 3 of Set 4 | praia da vitoria
# Processing Record 4 of Set 4 | alice springs
# Processing Record 5 of Set 4 | carnarvon
# Processing Record 6 of Set 4 | luderitz
# Processing Record 7 of Set 4 | guerrero negro
# Processing Record 8 of Set 4 | rincon
# Processing Record 9 of Set 4 | nikel
# Processing Record 10 of Set 4 | cheuskiny
# City not found. Skipping...
# Processing Record 11 of Set 4 | castro
# Processing Record 12 of Set 4 | nanortalik
# Processing Record 13 of Set 4 | sao felix do xingu
# Processing Record 14 of Set 4 | lavrentiya
# Processing Record 15 of Set 4 | teya
# Processing Record 16 of Set 4 | carmo do paranaiba
# Processing Record 17 of Set 4 | gbadolite
# Processing Record 18 of Set 4 | thompson
# Processing Record 19 of Set 4 | vanimo
# Processing Record 20 of Set 4 | narkevychi
# Processing Record 21 of Set 4 | sayyan
# Processing Record 22 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 23 of Set 4 | fortuna
# Processing Record 24 of Set 4 | ribeira grande
# Processing Record 25 of Set 4 | sitka
# Processing Record 26 of Set 4 | le port
# Processing Record 27 of Set 4 | dikson
# Processing Record 28 of Set 4 | dauriya
# Processing Record 29 of Set 4 | alotau
# City not found. Skipping...
# Processing Record 30 of Set 4 | lebu
# Processing Record 31 of Set 4 | victoria
# Processing Record 32 of Set 4 | salalah
# Processing Record 33 of Set 4 | petropavlovsk-kamchatskiy
# Processing Record 34 of Set 4 | westport
# Processing Record 35 of Set 4 | canico
# Processing Record 36 of Set 4 | komsomolskiy
# Processing Record 37 of Set 4 | atambua
# Processing Record 38 of Set 4 | hualmay
# Processing Record 39 of Set 4 | deputatskiy
# Processing Record 40 of Set 4 | bredasdorp
# Processing Record 41 of Set 4 | zhangye
# Processing Record 42 of Set 4 | erzin
# Processing Record 43 of Set 4 | ixtapa
# Processing Record 44 of Set 4 | kulunda
# Processing Record 45 of Set 4 | sao filipe
# Processing Record 46 of Set 4 | sulecin
# Processing Record 47 of Set 4 | goderich
# Processing Record 48 of Set 4 | verkhnevilyuysk
# Processing Record 49 of Set 4 | abaetetuba
# Processing Record 50 of Set 4 | nelson bay
# Processing Record 1 of Set 5 | iqaluit
# Processing Record 2 of Set 5 | dover
# Processing Record 3 of Set 5 | el tigre
# Processing Record 4 of Set 5 | homer
# Processing Record 5 of Set 5 | yar-sale
# Processing Record 6 of Set 5 | lao cai
# Processing Record 7 of Set 5 | camana
# Processing Record 8 of Set 5 | gander
# Processing Record 9 of Set 5 | nakonde
# Processing Record 10 of Set 5 | tasiilaq
# Processing Record 11 of Set 5 | meadow lake
# Processing Record 12 of Set 5 | fukue
# Processing Record 13 of Set 5 | fort nelson
# Processing Record 14 of Set 5 | zhob
# Processing Record 15 of Set 5 | karratha
# Processing Record 16 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 17 of Set 5 | manoel urbano
# Processing Record 18 of Set 5 | wattegama
# Processing Record 19 of Set 5 | pangnirtung
# Processing Record 20 of Set 5 | barbosa ferraz
# Processing Record 21 of Set 5 | port hawkesbury
# Processing Record 22 of Set 5 | nouadhibou
# Processing Record 23 of Set 5 | campo maior
# Processing Record 24 of Set 5 | aklavik
# Processing Record 25 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 26 of Set 5 | dingle
# Processing Record 27 of Set 5 | nzerekore
# Processing Record 28 of Set 5 | de-kastri
# Processing Record 29 of Set 5 | tilichiki
# Processing Record 30 of Set 5 | bodden town
# Processing Record 31 of Set 5 | omsukchan
# Processing Record 32 of Set 5 | san vicente
# Processing Record 33 of Set 5 | shuangyang
# Processing Record 34 of Set 5 | lazaro cardenas
# Processing Record 35 of Set 5 | brainerd
# Processing Record 36 of Set 5 | esperance
# Processing Record 37 of Set 5 | bardiyah
# Processing Record 38 of Set 5 | san antonio
# Processing Record 39 of Set 5 | thinadhoo
# Processing Record 40 of Set 5 | gibsons
# Processing Record 41 of Set 5 | kaitangata
# Processing Record 42 of Set 5 | rockland
# Processing Record 43 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 44 of Set 5 | ponta do sol
# Processing Record 45 of Set 5 | jaslo
# Processing Record 46 of Set 5 | pevek
# Processing Record 47 of Set 5 | promyshlennovskiy
# Processing Record 48 of Set 5 | solnechnyy
# Processing Record 49 of Set 5 | bacolod
# Processing Record 50 of Set 5 | adrar
# Processing Record 1 of Set 6 | batemans bay
# Processing Record 2 of Set 6 | barentsburg
# City not found. Skipping...
# Processing Record 3 of Set 6 | ola
# Processing Record 4 of Set 6 | manuk mangkaw
# Processing Record 5 of Set 6 | zyryanka
# Processing Record 6 of Set 6 | villa carlos paz
# Processing Record 7 of Set 6 | marakkanam
# Processing Record 8 of Set 6 | sankt georgen
# Processing Record 9 of Set 6 | colesberg
# Processing Record 10 of Set 6 | asau
# Processing Record 11 of Set 6 | saskylakh
# Processing Record 12 of Set 6 | saint anthony
# Processing Record 13 of Set 6 | comodoro rivadavia
# Processing Record 14 of Set 6 | deniliquin
# Processing Record 15 of Set 6 | tungor
# Processing Record 16 of Set 6 | port lincoln
# Processing Record 17 of Set 6 | jabiru
# City not found. Skipping...
# Processing Record 18 of Set 6 | hilo
# Processing Record 19 of Set 6 | tezu
# Processing Record 20 of Set 6 | melita
# Processing Record 21 of Set 6 | oshkosh
# Processing Record 22 of Set 6 | mpraeso
# Processing Record 23 of Set 6 | xapuri
# Processing Record 24 of Set 6 | oranjemund
# Processing Record 25 of Set 6 | batagay-alyta
# Processing Record 26 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 27 of Set 6 | ravar
# Processing Record 28 of Set 6 | odemira
# Processing Record 29 of Set 6 | cairns
# Processing Record 30 of Set 6 | baiyin
# Processing Record 31 of Set 6 | havelock
# Processing Record 32 of Set 6 | tacoronte
# Processing Record 33 of Set 6 | walvis bay
# Processing Record 34 of Set 6 | nizhneudinsk
# Processing Record 35 of Set 6 | lakes entrance
# Processing Record 36 of Set 6 | lyubim
# Processing Record 37 of Set 6 | aguimes
# Processing Record 38 of Set 6 | springbok
# Processing Record 39 of Set 6 | srednekolymsk
# Processing Record 40 of Set 6 | puerto escondido
# Processing Record 41 of Set 6 | las matas de farfan
# Processing Record 42 of Set 6 | dembi dolo
# Processing Record 43 of Set 6 | urumqi
# Processing Record 44 of Set 6 | zhigalovo
# Processing Record 45 of Set 6 | baruun-urt
# Processing Record 46 of Set 6 | nhulunbuy
# Processing Record 47 of Set 6 | batagay
# Processing Record 48 of Set 6 | portland
# Processing Record 49 of Set 6 | kruisfontein
# Processing Record 50 of Set 6 | tongren
# Processing Record 1 of Set 7 | husavik
# Processing Record 2 of Set 7 | samalaeulu
# City not found. Skipping...
# Processing Record 3 of Set 7 | solovetskiy
# City not found. Skipping...
# Processing Record 4 of Set 7 | mar del plata
# Processing Record 5 of Set 7 | teknaf
# Processing Record 6 of Set 7 | bentiu
# Processing Record 7 of Set 7 | andenes
# Processing Record 8 of Set 7 | nyurba
# Processing Record 9 of Set 7 | harper
# Processing Record 10 of Set 7 | touros
# Processing Record 11 of Set 7 | conde
# Processing Record 12 of Set 7 | tolga
# Processing Record 13 of Set 7 | kleinmachnow
# Processing Record 14 of Set 7 | madison
# Processing Record 15 of Set 7 | halalo
# City not found. Skipping...
# Processing Record 16 of Set 7 | quatre cocos
# Processing Record 17 of Set 7 | beidao
# Processing Record 18 of Set 7 | matagami
# Processing Record 19 of Set 7 | riverton
# Processing Record 20 of Set 7 | qaqortoq
# Processing Record 21 of Set 7 | karacabey
# Processing Record 22 of Set 7 | lebanon
# Processing Record 23 of Set 7 | muros
# Processing Record 24 of Set 7 | derzhavinsk
# Processing Record 25 of Set 7 | fort saint john
# City not found. Skipping...
# Processing Record 26 of Set 7 | russell
# Processing Record 27 of Set 7 | bereda
# Processing Record 28 of Set 7 | north bend
# Processing Record 29 of Set 7 | qianan
# Processing Record 30 of Set 7 | banepa
# Processing Record 31 of Set 7 | kenai
# Processing Record 32 of Set 7 | tuburan
# Processing Record 33 of Set 7 | rocha
# Processing Record 34 of Set 7 | labytnangi
# Processing Record 35 of Set 7 | carutapera
# Processing Record 36 of Set 7 | jumla
# Processing Record 37 of Set 7 | singkang
# Processing Record 38 of Set 7 | adeje
# Processing Record 39 of Set 7 | nouakchott
# Processing Record 40 of Set 7 | palabuhanratu
# City not found. Skipping...
# Processing Record 41 of Set 7 | ilulissat
# Processing Record 42 of Set 7 | sabzevar
# Processing Record 43 of Set 7 | nyagan
# Processing Record 44 of Set 7 | pietarsaari
# Processing Record 45 of Set 7 | vasteras
# Processing Record 46 of Set 7 | shache
# Processing Record 47 of Set 7 | chenzhou
# Processing Record 48 of Set 7 | berezovyy
# Processing Record 49 of Set 7 | fairview
# Processing Record 50 of Set 7 | rawson
# Processing Record 1 of Set 8 | charters towers
# Processing Record 2 of Set 8 | kibala
# Processing Record 3 of Set 8 | gigmoto
# Processing Record 4 of Set 8 | mayskiy
# Processing Record 5 of Set 8 | anyksciai
# Processing Record 6 of Set 8 | louisbourg
# City not found. Skipping...
# Processing Record 7 of Set 8 | lar
# Processing Record 8 of Set 8 | wolfeboro
# Processing Record 9 of Set 8 | solton
# Processing Record 10 of Set 8 | price
# Processing Record 11 of Set 8 | mulheim-karlich
# Processing Record 12 of Set 8 | teresina
# Processing Record 13 of Set 8 | itoman
# Processing Record 14 of Set 8 | sinjar
# Processing Record 15 of Set 8 | rawannawi
# City not found. Skipping...
# Processing Record 16 of Set 8 | nantucket
# Processing Record 17 of Set 8 | lolua
# City not found. Skipping...
# Processing Record 18 of Set 8 | fenoarivo
# Processing Record 19 of Set 8 | norman wells
# Processing Record 20 of Set 8 | tigil
# Processing Record 21 of Set 8 | kerteh
# City not found. Skipping...
# Processing Record 22 of Set 8 | harlingen
# Processing Record 23 of Set 8 | rani
# Processing Record 24 of Set 8 | cabo san lucas
# Processing Record 25 of Set 8 | broken hill
# Processing Record 26 of Set 8 | mbamba
# Processing Record 27 of Set 8 | koyilandi
# City not found. Skipping...
# Processing Record 28 of Set 8 | alpena
# Processing Record 29 of Set 8 | ratlam
# Processing Record 30 of Set 8 | bilibino
# Processing Record 31 of Set 8 | ballina
# Processing Record 32 of Set 8 | palmer
# Processing Record 33 of Set 8 | salaya
# Processing Record 34 of Set 8 | muyezerskiy
# Processing Record 35 of Set 8 | machali
# Processing Record 36 of Set 8 | taltal
# Processing Record 37 of Set 8 | paita
# Processing Record 38 of Set 8 | belyy yar
# Processing Record 39 of Set 8 | paamiut
# Processing Record 40 of Set 8 | abu dhabi
# Processing Record 41 of Set 8 | finnsnes
# Processing Record 42 of Set 8 | staryy nadym
# Processing Record 43 of Set 8 | joshimath
# Processing Record 44 of Set 8 | hobbs
# Processing Record 45 of Set 8 | ostrovnoy
# Processing Record 46 of Set 8 | wokha
# Processing Record 47 of Set 8 | sobolevo
# Processing Record 48 of Set 8 | domodossola
# Processing Record 49 of Set 8 | kulhudhuffushi
# Processing Record 50 of Set 8 | poplar bluff
# Processing Record 1 of Set 9 | khonuu
# City not found. Skipping...
# Processing Record 2 of Set 9 | senaki
# Processing Record 3 of Set 9 | kyzyl
# Processing Record 4 of Set 9 | bontang
# Processing Record 5 of Set 9 | veraval
# Processing Record 6 of Set 9 | santa cruz de tenerife
# Processing Record 7 of Set 9 | kodiak
# Processing Record 8 of Set 9 | inongo
# Processing Record 9 of Set 9 | hasaki
# Processing Record 10 of Set 9 | kadykchan
# City not found. Skipping...
# Processing Record 11 of Set 9 | torello
# Processing Record 12 of Set 9 | katsuura
# Processing Record 13 of Set 9 | benavente
# Processing Record 14 of Set 9 | awbari
# Processing Record 15 of Set 9 | henties bay
# Processing Record 16 of Set 9 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 17 of Set 9 | nenjiang
# Processing Record 18 of Set 9 | sorong
# Processing Record 19 of Set 9 | jiangyou
# Processing Record 20 of Set 9 | namatanai
# Processing Record 21 of Set 9 | urdzhar
# City not found. Skipping...
# Processing Record 22 of Set 9 | kirakira
# Processing Record 23 of Set 9 | soyo
# Processing Record 24 of Set 9 | arys
# Processing Record 25 of Set 9 | lincoln
# Processing Record 26 of Set 9 | karmana
# City not found. Skipping...
# Processing Record 27 of Set 9 | nishihara
# Processing Record 28 of Set 9 | stephenville
# Processing Record 29 of Set 9 | garowe
# Processing Record 30 of Set 9 | careiro da varzea
# Processing Record 31 of Set 9 | thohoyandou
# Processing Record 32 of Set 9 | mosina
# Processing Record 33 of Set 9 | pisco
# Processing Record 34 of Set 9 | beringovskiy
# Processing Record 35 of Set 9 | estreito
# Processing Record 36 of Set 9 | ancud
# Processing Record 37 of Set 9 | dhari
# Processing Record 38 of Set 9 | skalistyy
# City not found. Skipping...
# Processing Record 39 of Set 9 | nadym
# Processing Record 40 of Set 9 | marienburg
# Processing Record 41 of Set 9 | cabedelo
# Processing Record 42 of Set 9 | kochi
# Processing Record 43 of Set 9 | shelburne
# Processing Record 44 of Set 9 | bubaque
# Processing Record 45 of Set 9 | erenhot
# Processing Record 46 of Set 9 | nador
# Processing Record 47 of Set 9 | lichtenburg
# Processing Record 48 of Set 9 | oktyabrskiy
# Processing Record 49 of Set 9 | kristiinankaupunki
# Processing Record 50 of Set 9 | grand centre
# City not found. Skipping...
# Processing Record 1 of Set 10 | edgewater
# Processing Record 2 of Set 10 | leningradskiy
# Processing Record 3 of Set 10 | caravelas
# Processing Record 4 of Set 10 | alofi
# Processing Record 5 of Set 10 | belmonte
# Processing Record 6 of Set 10 | san luis
# Processing Record 7 of Set 10 | esmeraldas
# Processing Record 8 of Set 10 | salo
# Processing Record 9 of Set 10 | kuching
# Processing Record 10 of Set 10 | straumen
# Processing Record 11 of Set 10 | trinidad
# Processing Record 12 of Set 10 | shorapani
# Processing Record 13 of Set 10 | fare
# Processing Record 14 of Set 10 | cao bang
# Processing Record 15 of Set 10 | namibe
# Processing Record 16 of Set 10 | geraldton
# Processing Record 17 of Set 10 | zhaozhou
# Processing Record 18 of Set 10 | danane
# Processing Record 19 of Set 10 | vanino
# Processing Record 20 of Set 10 | praia
# Processing Record 21 of Set 10 | buon me thuot
# City not found. Skipping...
# Processing Record 22 of Set 10 | nuuk
# Processing Record 23 of Set 10 | quesnel
# Processing Record 24 of Set 10 | sarkand
# Processing Record 25 of Set 10 | mujiayingzi
# Processing Record 26 of Set 10 | leninskiy
# Processing Record 27 of Set 10 | zhangjiakou
# Processing Record 28 of Set 10 | marcona
# City not found. Skipping...
# Processing Record 29 of Set 10 | mindelo
# Processing Record 30 of Set 10 | roald
# Processing Record 31 of Set 10 | hervey bay
# Processing Record 32 of Set 10 | manjeri
# Processing Record 33 of Set 10 | matay
# Processing Record 34 of Set 10 | kirkwall
# Processing Record 35 of Set 10 | amahai
# Processing Record 36 of Set 10 | port augusta
# Processing Record 37 of Set 10 | san rafael
# Processing Record 38 of Set 10 | uinskoye
# Processing Record 39 of Set 10 | santa vitoria do palmar
# Processing Record 40 of Set 10 | darab
# Processing Record 41 of Set 10 | punta cardon
# Processing Record 42 of Set 10 | macusani
# Processing Record 43 of Set 10 | los arabos
# Processing Record 44 of Set 10 | marsh harbour
# Processing Record 45 of Set 10 | quelimane
# Processing Record 46 of Set 10 | fort-shevchenko
# Processing Record 47 of Set 10 | barao de melgaco
# Processing Record 48 of Set 10 | korcula
# Processing Record 49 of Set 10 | amga
# Processing Record 50 of Set 10 | vestmannaeyjar
# Processing Record 1 of Set 11 | lesnoye
# Processing Record 2 of Set 11 | kavaratti
# Processing Record 3 of Set 11 | saldanha
# Processing Record 4 of Set 11 | jalu
# Processing Record 5 of Set 11 | coffs harbour
# Processing Record 6 of Set 11 | longyearbyen
# Processing Record 7 of Set 11 | tabiauea
# City not found. Skipping...
# Processing Record 8 of Set 11 | innisfail
# Processing Record 9 of Set 11 | berlevag
# Processing Record 10 of Set 11 | abeche
# Processing Record 11 of Set 11 | manzil tamim
# City not found. Skipping...
# Processing Record 12 of Set 11 | patitirion
# Processing Record 13 of Set 11 | ust-maya
# Processing Record 14 of Set 11 | killarney
# Processing Record 15 of Set 11 | guerande
# Processing Record 16 of Set 11 | la primavera
# Processing Record 17 of Set 11 | kafanchan
# Processing Record 18 of Set 11 | laguna
# Processing Record 19 of Set 11 | sorvag
# City not found. Skipping...
# Processing Record 20 of Set 11 | naron
# Processing Record 21 of Set 11 | bajo baudo
# City not found. Skipping...
# Processing Record 22 of Set 11 | naze
# Processing Record 23 of Set 11 | luanda
# Processing Record 24 of Set 11 | xining
# Processing Record 25 of Set 11 | bozdar
# Processing Record 26 of Set 11 | kipushi
# Processing Record 27 of Set 11 | igarka
# Processing Record 28 of Set 11 | atherton
# Processing Record 29 of Set 11 | san blas
# Processing Record 30 of Set 11 | billings
# Processing Record 31 of Set 11 | pochutla
# Processing Record 32 of Set 11 | bose
# Processing Record 33 of Set 11 | kenora
# Processing Record 34 of Set 11 | iracoubo
# Processing Record 35 of Set 11 | mount isa
# Processing Record 36 of Set 11 | chavakkad
# Processing Record 37 of Set 11 | christchurch
# Processing Record 38 of Set 11 | tshikapa
# Processing Record 39 of Set 11 | muscat
# Processing Record 40 of Set 11 | storsteinnes
# Processing Record 41 of Set 11 | briancon
# Processing Record 42 of Set 11 | malakal
# Processing Record 43 of Set 11 | dunedin
# Processing Record 44 of Set 11 | shimoda
# Processing Record 45 of Set 11 | pozo colorado
# Processing Record 46 of Set 11 | diebougou
# Processing Record 47 of Set 11 | beloha
# Processing Record 48 of Set 11 | aqtobe
# Processing Record 49 of Set 11 | maridi
# Processing Record 50 of Set 11 | saint george
# Processing Record 1 of Set 12 | kushikino
# Processing Record 2 of Set 12 | kiomboi
# Processing Record 3 of Set 12 | poum
# Processing Record 4 of Set 12 | celina
# Processing Record 5 of Set 12 | zwedru
# Processing Record 6 of Set 12 | tibati
# Processing Record 7 of Set 12 | mizan teferi
# Processing Record 8 of Set 12 | te anau
# Processing Record 9 of Set 12 | levelland
# Processing Record 10 of Set 12 | skagastrond
# City not found. Skipping...
# Processing Record 11 of Set 12 | kandrian
# Processing Record 12 of Set 12 | smoljan
# Processing Record 13 of Set 12 | hofn
# Processing Record 14 of Set 12 | ambatofinandrahana
# Processing Record 15 of Set 12 | havoysund
# Processing Record 16 of Set 12 | nioro
# Processing Record 17 of Set 12 | amapa
# Processing Record 18 of Set 12 | muli
# Processing Record 19 of Set 12 | gazanjyk
# Processing Record 20 of Set 12 | dubbo
# Processing Record 21 of Set 12 | kozhva
# Processing Record 22 of Set 12 | zverinogolovskoye
# Processing Record 23 of Set 12 | kaeo
# Processing Record 24 of Set 12 | roswell
# Processing Record 25 of Set 12 | guanare
# Processing Record 26 of Set 12 | maykain
# City not found. Skipping...
# Processing Record 27 of Set 12 | nome
# Processing Record 28 of Set 12 | rayong
# Processing Record 29 of Set 12 | bambanglipuro
# Processing Record 30 of Set 12 | tucurui
# Processing Record 31 of Set 12 | auki
# Processing Record 32 of Set 12 | narsingi
# Processing Record 33 of Set 12 | verkhoyansk
# Processing Record 34 of Set 12 | kongsberg
# Processing Record 35 of Set 12 | alghero
# Processing Record 36 of Set 12 | lata
# Processing Record 37 of Set 12 | kamenskoye
# City not found. Skipping...
# Processing Record 38 of Set 12 | sheridan
# Processing Record 39 of Set 12 | hirtshals
# Processing Record 40 of Set 12 | ejura
# Processing Record 41 of Set 12 | peterhead
# Processing Record 42 of Set 12 | san quintin
# Processing Record 43 of Set 12 | bolungarvik
# City not found. Skipping...
# Processing Record 44 of Set 12 | dossor
# Processing Record 45 of Set 12 | ushibuka
# Processing Record 46 of Set 12 | cabanas
# Processing Record 47 of Set 12 | luancheng
# Processing Record 48 of Set 12 | gainesville
# Processing Record 49 of Set 12 | ponta delgada
# Processing Record 50 of Set 12 | sabha
# Processing Record 1 of Set 13 | mayor pablo lagerenza
# Processing Record 2 of Set 13 | haines junction
# Processing Record 3 of Set 13 | berberati
# Processing Record 4 of Set 13 | sorland
# Processing Record 5 of Set 13 | ravels
# Processing Record 6 of Set 13 | naryan-mar
# Processing Record 7 of Set 13 | tyukalinsk
# Processing Record 8 of Set 13 | lasa
# Processing Record 9 of Set 13 | roebourne
# Processing Record 10 of Set 13 | luchegorsk
# Processing Record 11 of Set 13 | arkadelphia
# Processing Record 12 of Set 13 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 13 of Set 13 | aden
# Processing Record 14 of Set 13 | linjiang
# Processing Record 15 of Set 13 | mantenopolis
# Processing Record 16 of Set 13 | mirpur bathoro
# City not found. Skipping...
# Processing Record 17 of Set 13 | mangaluru
# Processing Record 18 of Set 13 | chaupal
# Processing Record 19 of Set 13 | korla
# Processing Record 20 of Set 13 | galgani
# City not found. Skipping...
# Processing Record 21 of Set 13 | kichera
# Processing Record 22 of Set 13 | bathsheba
# Processing Record 23 of Set 13 | itupiranga
# Processing Record 24 of Set 13 | brae
# Processing Record 25 of Set 13 | aventura
# Processing Record 26 of Set 13 | malwan
# City not found. Skipping...
# Processing Record 27 of Set 13 | skelleftea
# Processing Record 28 of Set 13 | pahrump
# Processing Record 29 of Set 13 | koungou
# Processing Record 30 of Set 13 | balkanabat
# Processing Record 31 of Set 13 | upington
# Processing Record 32 of Set 13 | teguldet
# Processing Record 33 of Set 13 | wanlaweyn
# Processing Record 34 of Set 13 | awjilah
# Processing Record 35 of Set 13 | kandi
# Processing Record 36 of Set 13 | parabel
# Processing Record 37 of Set 13 | brookhaven
# Processing Record 38 of Set 13 | sambava
# Processing Record 39 of Set 13 | mandalgovi
# Processing Record 40 of Set 13 | ewa beach
# Processing Record 41 of Set 13 | hambantota
# Processing Record 42 of Set 13 | sirajganj
# Processing Record 43 of Set 13 | fort dix
# Processing Record 44 of Set 13 | coquimbo
# Processing Record 45 of Set 13 | port-gentil
# Processing Record 46 of Set 13 | manta
# Processing Record 47 of Set 13 | oistins
# Processing Record 48 of Set 13 | udachnyy
# Processing Record 49 of Set 13 | moree
# Processing Record 50 of Set 13 | waingapu
# Processing Record 1 of Set 14 | vila franca do campo
# Processing Record 2 of Set 14 | yaroslavskaya
# Processing Record 3 of Set 14 | tautira
# Processing Record 4 of Set 14 | tiznit
# Processing Record 5 of Set 14 | barcelos
# Processing Record 6 of Set 14 | pionerskiy
# Processing Record 7 of Set 14 | higuey
# City not found. Skipping...
# Processing Record 8 of Set 14 | penzance
# Processing Record 9 of Set 14 | vallenar
# Processing Record 10 of Set 14 | maramba
# Processing Record 11 of Set 14 | lamar
# Processing Record 12 of Set 14 | apac
# Processing Record 13 of Set 14 | fountain hills
# Processing Record 14 of Set 14 | katherine
# Processing Record 15 of Set 14 | kiama
# Processing Record 16 of Set 14 | boende
# Processing Record 17 of Set 14 | gornopravdinsk
# Processing Record 18 of Set 14 | buraydah
# Processing Record 19 of Set 14 | oron
# Processing Record 20 of Set 14 | constitucion
# Processing Record 21 of Set 14 | umm bab
# Processing Record 22 of Set 14 | copiapo
# Processing Record 23 of Set 14 | yumen
# Processing Record 24 of Set 14 | shenjiamen
# Processing Record 25 of Set 14 | vestmanna
# Processing Record 26 of Set 14 | puerto del rosario
# Processing Record 27 of Set 14 | aurillac
# Processing Record 28 of Set 14 | tunduru
# City not found. Skipping...
# Processing Record 29 of Set 14 | sal rei
# Processing Record 30 of Set 14 | ningxiang
# Processing Record 31 of Set 14 | zemaiciu naumiestis
# Processing Record 32 of Set 14 | gubkinskiy
# Processing Record 33 of Set 14 | coahuayana
# Processing Record 34 of Set 14 | sampit
# Processing Record 35 of Set 14 | svetlaya
# Processing Record 36 of Set 14 | khorixas
# Processing Record 37 of Set 14 | west bay
# Processing Record 38 of Set 14 | myaundzha
# Processing Record 39 of Set 14 | nemuro
# Processing Record 40 of Set 14 | khartoum
# Processing Record 41 of Set 14 | gambo
# Processing Record 42 of Set 14 | mount gambier
# Processing Record 43 of Set 14 | najran
# Processing Record 44 of Set 14 | glenwood springs
# Processing Record 45 of Set 14 | hihifo
# City not found. Skipping...
# Processing Record 46 of Set 14 | obo
# Processing Record 47 of Set 14 | aksarka
# Processing Record 48 of Set 14 | simav
# Processing Record 49 of Set 14 | juba
# Processing Record 50 of Set 14 | rio gallegos
# Processing Record 1 of Set 15 | kristinehamn
# Processing Record 2 of Set 15 | aykhal
# Processing Record 3 of Set 15 | half moon bay
# Processing Record 4 of Set 15 | mahajanga
# Processing Record 5 of Set 15 | severnyy
# Processing Record 6 of Set 15 | harsin
# Processing Record 7 of Set 15 | richards bay
# Processing Record 8 of Set 15 | san lorenzo
# Processing Record 9 of Set 15 | mersing
# Processing Record 10 of Set 15 | itarema
# Processing Record 11 of Set 15 | jaguaruana
# Processing Record 12 of Set 15 | victoria point
# Processing Record 13 of Set 15 | kropotkin
# Processing Record 14 of Set 15 | ginda
# Processing Record 15 of Set 15 | egvekinot
# Processing Record 16 of Set 15 | bonthe
# Processing Record 17 of Set 15 | ahumada
# City not found. Skipping...
# Processing Record 18 of Set 15 | olmos
# Processing Record 19 of Set 15 | sur
# Processing Record 20 of Set 15 | escanaba
# Processing Record 21 of Set 15 | zatoka
# Processing Record 22 of Set 15 | gladstone
# Processing Record 23 of Set 15 | zolotinka
# City not found. Skipping...
# Processing Record 24 of Set 15 | newport
# Processing Record 25 of Set 15 | sagua de tanamo
# Processing Record 26 of Set 15 | port hardy
# Processing Record 27 of Set 15 | muzhi
# Processing Record 28 of Set 15 | at-bashi
# Processing Record 29 of Set 15 | sovetsk
# Processing Record 30 of Set 15 | marshfield
# Processing Record 31 of Set 15 | strezhevoy
# Processing Record 32 of Set 15 | challapata
# Processing Record 33 of Set 15 | coxim
# Processing Record 34 of Set 15 | chagda
# City not found. Skipping...
# Processing Record 35 of Set 15 | assela
# City not found. Skipping...
# Processing Record 36 of Set 15 | libreville
# Processing Record 37 of Set 15 | labuhan
# Processing Record 38 of Set 15 | san cristobal
# Processing Record 39 of Set 15 | katesh
# Processing Record 40 of Set 15 | bargal
# City not found. Skipping...
# Processing Record 41 of Set 15 | tlacotepec
# Processing Record 42 of Set 15 | whitianga
# Processing Record 43 of Set 15 | ambilobe
# Processing Record 44 of Set 15 | turbat
# Processing Record 45 of Set 15 | honiara
# Processing Record 46 of Set 15 | kimberley
# Processing Record 47 of Set 15 | sovetskiy
# Processing Record 48 of Set 15 | san buenaventura
# Processing Record 49 of Set 15 | bandarban
# Processing Record 50 of Set 15 | pimenta bueno
# Processing Record 1 of Set 16 | carballo
# Processing Record 2 of Set 16 | ternovka
# Processing Record 3 of Set 16 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 4 of Set 16 | posse
# Processing Record 5 of Set 16 | taquarana
# Processing Record 6 of Set 16 | gao
# Processing Record 7 of Set 16 | margate
# Processing Record 8 of Set 16 | lerwick
# Processing Record 9 of Set 16 | basoko
# Processing Record 10 of Set 16 | roma
# Processing Record 11 of Set 16 | george
# Processing Record 12 of Set 16 | moorhead
# Processing Record 13 of Set 16 | mount darwin
# Processing Record 14 of Set 16 | vila velha
# Processing Record 15 of Set 16 | kalianget
# Processing Record 16 of Set 16 | talnakh
# Processing Record 17 of Set 16 | tura
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     East London      ZA -33.0153   27.9116     56.55        59          51
# 1          Albany      US  42.6001  -73.9662     67.15        92          92
# 2         Mataura      NZ -46.1927  168.8643     53.47        45          13
# 3  Port Elizabeth      ZA -33.9180   25.5701     46.09        75          21
# 4         Samarai      PG -10.6167  150.6667     78.48        84         100
# 5        Lovozero      RU  68.0050   35.0117     38.77        93         100
# 6           Kapaa      US  22.0752 -159.3190     82.38        71          97
# 7         Kavieng      PG  -2.5744  150.7967     83.77        76          32
# 8          Lompoc      US  34.6391 -120.4579     60.01        83           1
# 9       Boa Vista      BR   2.8197  -60.6733     78.78        78          20
#
#    Wind Speed Current Description
# 0        3.09       broken clouds
# 1        3.20     overcast clouds
# 2        2.15          few clouds
# 3        6.35          few clouds
# 4       19.01     overcast clouds
# 5        4.21     overcast clouds
# 6        5.01     overcast clouds
# 7       14.23          light rain
# 8        3.44           clear sky
# 9        3.44          few clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
