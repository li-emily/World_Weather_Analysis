# %%
# Create a new set of 2,000 random latitudes and longitudes.

# Get the nearest city using the citipy module.

# Perform an API call with the OpenWeatherMap.

# Retrieve the Following
    # Latitude and longitude
    # Maximum temperature
    # Percent humidity
    # Percent cloudiness
    # Wind speed
    # Weather description (for example, clouds, fog, light rain, clear sky)
    
# Add the data to a new DataFrame
# Export the DataFrame as a CSV file, and save it as WeatherPy_Database.csv in the Weather_Database folder.

# %%
# Import the dependencies.
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt


from citipy import citipy
from config import weather_api_key
import requests
from datetime import datetime

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | hithadhoo
# Processing Record 2 of Set 1 | hilo
# Processing Record 3 of Set 1 | bengkulu
# Processing Record 4 of Set 1 | rikitea
# Processing Record 5 of Set 1 | atuona
# Processing Record 6 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 7 of Set 1 | aklavik
# Processing Record 8 of Set 1 | vestmannaeyjar
# Processing Record 9 of Set 1 | mahebourg
# Processing Record 10 of Set 1 | kortkeros
# Processing Record 11 of Set 1 | dunedin
# Processing Record 12 of Set 1 | lebu
# Processing Record 13 of Set 1 | butaritari
# Processing Record 14 of Set 1 | tasiilaq
# Processing Record 15 of Set 1 | severo-kurilsk
# Processing Record 16 of Set 1 | evensk
# Processing Record 17 of Set 1 | nuuk
# Processing Record 18 of Set 1 | mount gambier
# Processing Record 19 of Set 1 | vardo
# Processing Record 20 of Set 1 | nikolskoye
# Processing Record 21 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 22 of Set 1 | ribeira grande
# Processing Record 23 of Set 1 | lavrentiya
# Processing Record 24 of Set 1 | axim
# Processing Record 25 of Set 1 | saint-philippe
# Processing Record 26 of Set 1 | port alfred
# Processing Record 27 of Set 1 | touros
# Processing Record 28 of Set 1 | souillac
# Processing Record 29 of Set 1 | bambous virieux
# Processing Record 30 of Set 1 | nemcice nad hanou
# Processing Record 31 of Set 1 | cleveland
# Processing Record 32 of Set 1 | airai
# Processing Record 33 of Set 1 | boa vista
# Processing Record 34 of Set 1 | komsomolskiy
# Processing Record 35 of Set 1 | albany
# Processing Record 36 of Set 1 | bethel
# Processing Record 37 of Set 1 | korla
# Processing Record 38 of Set 1 | jamestown
# Processing Record 39 of Set 1 | faanui
# Processing Record 40 of Set 1 | pingliang
# Processing Record 41 of Set 1 | shache
# Processing Record 42 of Set 1 | tumannyy
# City not found. Skipping...
# Processing Record 43 of Set 1 | clyde river
# Processing Record 44 of Set 1 | mataura
# Processing Record 45 of Set 1 | bluff
# Processing Record 46 of Set 1 | kaitangata
# Processing Record 47 of Set 1 | lamar
# Processing Record 48 of Set 1 | torbay
# Processing Record 49 of Set 1 | provideniya
# Processing Record 50 of Set 1 | poronaysk
# Processing Record 1 of Set 2 | nanakuli
# Processing Record 2 of Set 2 | pevek
# Processing Record 3 of Set 2 | palabuhanratu
# City not found. Skipping...
# Processing Record 4 of Set 2 | igarka
# Processing Record 5 of Set 2 | zvishavane
# Processing Record 6 of Set 2 | carnarvon
# Processing Record 7 of Set 2 | hobart
# Processing Record 8 of Set 2 | eureka
# Processing Record 9 of Set 2 | esperance
# Processing Record 10 of Set 2 | cape town
# Processing Record 11 of Set 2 | seryshevo
# Processing Record 12 of Set 2 | vaini
# Processing Record 13 of Set 2 | guerrero negro
# Processing Record 14 of Set 2 | ushuaia
# Processing Record 15 of Set 2 | hermanus
# Processing Record 16 of Set 2 | tautira
# Processing Record 17 of Set 2 | rio gallegos
# Processing Record 18 of Set 2 | muros
# Processing Record 19 of Set 2 | avarua
# Processing Record 20 of Set 2 | kutum
# Processing Record 21 of Set 2 | cockburn town
# Processing Record 22 of Set 2 | sangar
# Processing Record 23 of Set 2 | vila velha
# Processing Record 24 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 25 of Set 2 | tuggurt
# City not found. Skipping...
# Processing Record 26 of Set 2 | chokurdakh
# Processing Record 27 of Set 2 | marzuq
# Processing Record 28 of Set 2 | hobyo
# Processing Record 29 of Set 2 | nouadhibou
# Processing Record 30 of Set 2 | tikrit
# Processing Record 31 of Set 2 | tabuk
# Processing Record 32 of Set 2 | wamba
# Processing Record 33 of Set 2 | mitsamiouli
# Processing Record 34 of Set 2 | salalah
# Processing Record 35 of Set 2 | punta arenas
# Processing Record 36 of Set 2 | kilimatinde
# Processing Record 37 of Set 2 | ridgecrest
# Processing Record 38 of Set 2 | dikson
# Processing Record 39 of Set 2 | berezovyy
# Processing Record 40 of Set 2 | alice springs
# Processing Record 41 of Set 2 | taoudenni
# Processing Record 42 of Set 2 | epitalion
# Processing Record 43 of Set 2 | tiksi
# Processing Record 44 of Set 2 | khandbari
# Processing Record 45 of Set 2 | bonito
# Processing Record 46 of Set 2 | new norfolk
# Processing Record 47 of Set 2 | puerto ayora
# Processing Record 48 of Set 2 | bandarbeyla
# Processing Record 49 of Set 2 | mahadday weyne
# City not found. Skipping...
# Processing Record 50 of Set 2 | victoria
# Processing Record 1 of Set 3 | katsuura
# Processing Record 2 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 3 of Set 3 | port lincoln
# Processing Record 4 of Set 3 | busselton
# Processing Record 5 of Set 3 | chuy
# Processing Record 6 of Set 3 | kodiak
# Processing Record 7 of Set 3 | kropotkin
# Processing Record 8 of Set 3 | homer
# Processing Record 9 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 10 of Set 3 | saskylakh
# Processing Record 11 of Set 3 | east london
# Processing Record 12 of Set 3 | sao filipe
# Processing Record 13 of Set 3 | ponta delgada
# Processing Record 14 of Set 3 | rocha
# Processing Record 15 of Set 3 | pimentel
# Processing Record 16 of Set 3 | ponta do sol
# Processing Record 17 of Set 3 | awjilah
# Processing Record 18 of Set 3 | yellowknife
# Processing Record 19 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 20 of Set 3 | general pico
# Processing Record 21 of Set 3 | washougal
# Processing Record 22 of Set 3 | ancud
# Processing Record 23 of Set 3 | rio grande
# Processing Record 24 of Set 3 | saint george
# Processing Record 25 of Set 3 | tuktoyaktuk
# Processing Record 26 of Set 3 | coos bay
# Processing Record 27 of Set 3 | sitka
# Processing Record 28 of Set 3 | port arthur
# Processing Record 29 of Set 3 | kyren
# Processing Record 30 of Set 3 | naze
# Processing Record 31 of Set 3 | bud
# Processing Record 32 of Set 3 | san cristobal
# Processing Record 33 of Set 3 | mildura
# Processing Record 34 of Set 3 | bolungarvik
# City not found. Skipping...
# Processing Record 35 of Set 3 | iskateley
# Processing Record 36 of Set 3 | conde
# Processing Record 37 of Set 3 | tessalit
# Processing Record 38 of Set 3 | lata
# Processing Record 39 of Set 3 | dafeng
# Processing Record 40 of Set 3 | upernavik
# Processing Record 41 of Set 3 | port-gentil
# Processing Record 42 of Set 3 | russell
# Processing Record 43 of Set 3 | thompson
# Processing Record 44 of Set 3 | mazatlan
# Processing Record 45 of Set 3 | saint-leu
# Processing Record 46 of Set 3 | fairbanks
# Processing Record 47 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 48 of Set 3 | kapaa
# Processing Record 49 of Set 3 | wajid
# Processing Record 50 of Set 3 | campbell river
# Processing Record 1 of Set 4 | fairlie
# Processing Record 2 of Set 4 | coolum beach
# Processing Record 3 of Set 4 | bredasdorp
# Processing Record 4 of Set 4 | rockhampton
# Processing Record 5 of Set 4 | dorado
# Processing Record 6 of Set 4 | saint-joseph
# Processing Record 7 of Set 4 | san rafael
# Processing Record 8 of Set 4 | artyk
# City not found. Skipping...
# Processing Record 9 of Set 4 | cidreira
# Processing Record 10 of Set 4 | mar del plata
# Processing Record 11 of Set 4 | saint-pierre
# Processing Record 12 of Set 4 | jizan
# Processing Record 13 of Set 4 | vila franca do campo
# Processing Record 14 of Set 4 | nome
# Processing Record 15 of Set 4 | poya
# Processing Record 16 of Set 4 | cherskiy
# Processing Record 17 of Set 4 | anadyr
# Processing Record 18 of Set 4 | khatanga
# Processing Record 19 of Set 4 | antalaha
# Processing Record 20 of Set 4 | yen bai
# Processing Record 21 of Set 4 | severnyy
# Processing Record 22 of Set 4 | americana
# Processing Record 23 of Set 4 | ilulissat
# Processing Record 24 of Set 4 | ciudad ojeda
# Processing Record 25 of Set 4 | castro
# Processing Record 26 of Set 4 | fortuna
# Processing Record 27 of Set 4 | ngukurr
# City not found. Skipping...
# Processing Record 28 of Set 4 | barrow
# Processing Record 29 of Set 4 | zhicheng
# Processing Record 30 of Set 4 | lompoc
# Processing Record 31 of Set 4 | krasnoselkup
# Processing Record 32 of Set 4 | coihaique
# Processing Record 33 of Set 4 | alofi
# Processing Record 34 of Set 4 | fernie
# Processing Record 35 of Set 4 | gouyave
# Processing Record 36 of Set 4 | la ronge
# Processing Record 37 of Set 4 | flinders
# Processing Record 38 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 39 of Set 4 | coquimbo
# Processing Record 40 of Set 4 | rodez
# Processing Record 41 of Set 4 | revelstoke
# Processing Record 42 of Set 4 | qaanaaq
# Processing Record 43 of Set 4 | kawakawa
# Processing Record 44 of Set 4 | chiang kham
# Processing Record 45 of Set 4 | iturbe
# Processing Record 46 of Set 4 | comodoro rivadavia
# Processing Record 47 of Set 4 | maxixe
# Processing Record 48 of Set 4 | kachug
# Processing Record 49 of Set 4 | namatanai
# Processing Record 50 of Set 4 | alugan
# Processing Record 1 of Set 5 | makakilo city
# Processing Record 2 of Set 5 | koumac
# Processing Record 3 of Set 5 | kulhudhuffushi
# Processing Record 4 of Set 5 | japura
# Processing Record 5 of Set 5 | buribay
# Processing Record 6 of Set 5 | hofn
# Processing Record 7 of Set 5 | saurimo
# Processing Record 8 of Set 5 | laguna
# Processing Record 9 of Set 5 | gambela
# Processing Record 10 of Set 5 | buraydah
# Processing Record 11 of Set 5 | saldanha
# Processing Record 12 of Set 5 | yulara
# Processing Record 13 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 14 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 15 of Set 5 | kamuli
# Processing Record 16 of Set 5 | poso
# Processing Record 17 of Set 5 | kahului
# Processing Record 18 of Set 5 | sisimiut
# Processing Record 19 of Set 5 | georgetown
# Processing Record 20 of Set 5 | dubuque
# Processing Record 21 of Set 5 | morondava
# Processing Record 22 of Set 5 | pio ix
# Processing Record 23 of Set 5 | arraial do cabo
# Processing Record 24 of Set 5 | kenai
# Processing Record 25 of Set 5 | san patricio
# Processing Record 26 of Set 5 | filingue
# Processing Record 27 of Set 5 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 28 of Set 5 | yar-sale
# Processing Record 29 of Set 5 | mbini
# Processing Record 30 of Set 5 | roma
# Processing Record 31 of Set 5 | caravelas
# Processing Record 32 of Set 5 | teguise
# Processing Record 33 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 34 of Set 5 | saint-augustin
# Processing Record 35 of Set 5 | kruisfontein
# Processing Record 36 of Set 5 | novikovo
# Processing Record 37 of Set 5 | severnoye
# Processing Record 38 of Set 5 | rosetta
# Processing Record 39 of Set 5 | upington
# Processing Record 40 of Set 5 | krasnogorskiy
# Processing Record 41 of Set 5 | santa fe
# Processing Record 42 of Set 5 | dryden
# Processing Record 43 of Set 5 | pachino
# Processing Record 44 of Set 5 | guiyang
# Processing Record 45 of Set 5 | kampot
# Processing Record 46 of Set 5 | lasa
# Processing Record 47 of Set 5 | sabancuy
# Processing Record 48 of Set 5 | porto velho
# Processing Record 49 of Set 5 | nhulunbuy
# Processing Record 50 of Set 5 | toora-khem
# Processing Record 1 of Set 6 | okha
# Processing Record 2 of Set 6 | hihya
# Processing Record 3 of Set 6 | atasu
# Processing Record 4 of Set 6 | nguruka
# Processing Record 5 of Set 6 | port moresby
# Processing Record 6 of Set 6 | sola
# Processing Record 7 of Set 6 | abu dhabi
# Processing Record 8 of Set 6 | togur
# Processing Record 9 of Set 6 | malwan
# City not found. Skipping...
# Processing Record 10 of Set 6 | tura
# Processing Record 11 of Set 6 | hailar
# Processing Record 12 of Set 6 | lingyuan
# Processing Record 13 of Set 6 | elizabeth city
# Processing Record 14 of Set 6 | raahe
# Processing Record 15 of Set 6 | praia
# Processing Record 16 of Set 6 | scarborough
# Processing Record 17 of Set 6 | pavelets
# Processing Record 18 of Set 6 | lolua
# City not found. Skipping...
# Processing Record 19 of Set 6 | verkhniy tagil
# Processing Record 20 of Set 6 | dali
# Processing Record 21 of Set 6 | macomb
# Processing Record 22 of Set 6 | geraldton
# Processing Record 23 of Set 6 | teya
# Processing Record 24 of Set 6 | orlik
# Processing Record 25 of Set 6 | guzelyurt
# Processing Record 26 of Set 6 | yabrud
# Processing Record 27 of Set 6 | cabo san lucas
# Processing Record 28 of Set 6 | wulanhaote
# City not found. Skipping...
# Processing Record 29 of Set 6 | baturaja
# Processing Record 30 of Set 6 | pakxan
# Processing Record 31 of Set 6 | bystryy istok
# Processing Record 32 of Set 6 | araguatins
# City not found. Skipping...
# Processing Record 33 of Set 6 | mulki
# Processing Record 34 of Set 6 | aden
# Processing Record 35 of Set 6 | egvekinot
# Processing Record 36 of Set 6 | te anau
# Processing Record 37 of Set 6 | iisalmi
# Processing Record 38 of Set 6 | maceio
# Processing Record 39 of Set 6 | bolshoye selo
# Processing Record 40 of Set 6 | charters towers
# Processing Record 41 of Set 6 | altar
# Processing Record 42 of Set 6 | ormara
# Processing Record 43 of Set 6 | tuatapere
# Processing Record 44 of Set 6 | broome
# Processing Record 45 of Set 6 | gwadar
# Processing Record 46 of Set 6 | half moon bay
# Processing Record 47 of Set 6 | cayenne
# Processing Record 48 of Set 6 | mula
# Processing Record 49 of Set 6 | noumea
# Processing Record 50 of Set 6 | high level
# Processing Record 1 of Set 7 | ola
# Processing Record 2 of Set 7 | tilichiki
# Processing Record 3 of Set 7 | karpathos
# Processing Record 4 of Set 7 | acapulco
# Processing Record 5 of Set 7 | tsihombe
# City not found. Skipping...
# Processing Record 6 of Set 7 | mondlo
# Processing Record 7 of Set 7 | shingu
# Processing Record 8 of Set 7 | beoumi
# Processing Record 9 of Set 7 | goderich
# Processing Record 10 of Set 7 | ambon
# Processing Record 11 of Set 7 | minyar
# Processing Record 12 of Set 7 | padang
# Processing Record 13 of Set 7 | aksu
# Processing Record 14 of Set 7 | hirara
# Processing Record 15 of Set 7 | college
# Processing Record 16 of Set 7 | varadero
# Processing Record 17 of Set 7 | bom jesus
# Processing Record 18 of Set 7 | luderitz
# Processing Record 19 of Set 7 | fuerte olimpo
# Processing Record 20 of Set 7 | port elizabeth
# Processing Record 21 of Set 7 | port hedland
# Processing Record 22 of Set 7 | santa ana
# Processing Record 23 of Set 7 | aporawan
# City not found. Skipping...
# Processing Record 24 of Set 7 | bathsheba
# Processing Record 25 of Set 7 | bray
# Processing Record 26 of Set 7 | bonga
# Processing Record 27 of Set 7 | bonaventure
# Processing Record 28 of Set 7 | palmer
# Processing Record 29 of Set 7 | monticello
# Processing Record 30 of Set 7 | zhanaozen
# Processing Record 31 of Set 7 | novyy urengoy
# Processing Record 32 of Set 7 | san nicolas
# Processing Record 33 of Set 7 | longyearbyen
# Processing Record 34 of Set 7 | mvomero
# Processing Record 35 of Set 7 | opuwo
# Processing Record 36 of Set 7 | sorland
# Processing Record 37 of Set 7 | narsaq
# Processing Record 38 of Set 7 | oriximina
# Processing Record 39 of Set 7 | isangel
# Processing Record 40 of Set 7 | san juan
# Processing Record 41 of Set 7 | fare
# Processing Record 42 of Set 7 | mamakan
# Processing Record 43 of Set 7 | tanete
# Processing Record 44 of Set 7 | marawi
# Processing Record 45 of Set 7 | la ricamarie
# Processing Record 46 of Set 7 | iralaya
# Processing Record 47 of Set 7 | ornskoldsvik
# Processing Record 48 of Set 7 | la tuque
# Processing Record 49 of Set 7 | rio branco
# Processing Record 50 of Set 7 | palencia
# Processing Record 1 of Set 8 | qena
# Processing Record 2 of Set 8 | horta
# Processing Record 3 of Set 8 | manzhouli
# Processing Record 4 of Set 8 | phayuha khiri
# Processing Record 5 of Set 8 | algeciras
# Processing Record 6 of Set 8 | norman wells
# Processing Record 7 of Set 8 | dhuwaran
# Processing Record 8 of Set 8 | hovd
# Processing Record 9 of Set 8 | vavuniya
# Processing Record 10 of Set 8 | vao
# Processing Record 11 of Set 8 | ketchikan
# Processing Record 12 of Set 8 | skjervoy
# Processing Record 13 of Set 8 | gardez
# Processing Record 14 of Set 8 | barquisimeto
# Processing Record 15 of Set 8 | monster
# Processing Record 16 of Set 8 | westpunt
# City not found. Skipping...
# Processing Record 17 of Set 8 | kuytun
# Processing Record 18 of Set 8 | sao gabriel
# Processing Record 19 of Set 8 | banyo
# Processing Record 20 of Set 8 | santa maria
# Processing Record 21 of Set 8 | poyarkovo
# Processing Record 22 of Set 8 | gobabis
# Processing Record 23 of Set 8 | ust-tsilma
# Processing Record 24 of Set 8 | iqaluit
# Processing Record 25 of Set 8 | ayagoz
# Processing Record 26 of Set 8 | zhuozhou
# City not found. Skipping...
# Processing Record 27 of Set 8 | yerbogachen
# Processing Record 28 of Set 8 | deputatskiy
# Processing Record 29 of Set 8 | chimbote
# Processing Record 30 of Set 8 | galesong
# Processing Record 31 of Set 8 | doctor juan leon mallorquin
# Processing Record 32 of Set 8 | husavik
# Processing Record 33 of Set 8 | arlit
# Processing Record 34 of Set 8 | karaul
# City not found. Skipping...
# Processing Record 35 of Set 8 | chicama
# Processing Record 36 of Set 8 | bayan
# Processing Record 37 of Set 8 | uvat
# Processing Record 38 of Set 8 | genhe
# Processing Record 39 of Set 8 | waipawa
# Processing Record 40 of Set 8 | avera
# Processing Record 41 of Set 8 | potsdam
# Processing Record 42 of Set 8 | sataua
# City not found. Skipping...
# Processing Record 43 of Set 8 | poum
# Processing Record 44 of Set 8 | lagos de moreno
# Processing Record 45 of Set 8 | beringovskiy
# Processing Record 46 of Set 8 | tanta
# Processing Record 47 of Set 8 | sur
# Processing Record 48 of Set 8 | yangambi
# Processing Record 49 of Set 8 | hasaki
# Processing Record 50 of Set 8 | causapscal
# Processing Record 1 of Set 9 | ardahan
# Processing Record 2 of Set 9 | aleksandrov gay
# Processing Record 3 of Set 9 | cordoba
# Processing Record 4 of Set 9 | south venice
# Processing Record 5 of Set 9 | ystad
# Processing Record 6 of Set 9 | paita
# Processing Record 7 of Set 9 | khartoum
# Processing Record 8 of Set 9 | mayor pablo lagerenza
# Processing Record 9 of Set 9 | kamaishi
# Processing Record 10 of Set 9 | nanortalik
# Processing Record 11 of Set 9 | pangody
# Processing Record 12 of Set 9 | la romana
# Processing Record 13 of Set 9 | sinjai
# Processing Record 14 of Set 9 | araouane
# Processing Record 15 of Set 9 | san matias
# Processing Record 16 of Set 9 | paamiut
# Processing Record 17 of Set 9 | royan
# Processing Record 18 of Set 9 | brae
# Processing Record 19 of Set 9 | bo
# City not found. Skipping...
# Processing Record 20 of Set 9 | alpena
# Processing Record 21 of Set 9 | grand gaube
# Processing Record 22 of Set 9 | glendive
# Processing Record 23 of Set 9 | dalvik
# Processing Record 24 of Set 9 | nichinan
# Processing Record 25 of Set 9 | coremas
# Processing Record 26 of Set 9 | gejiu
# Processing Record 27 of Set 9 | kodino
# Processing Record 28 of Set 9 | carutapera
# Processing Record 29 of Set 9 | vestmanna
# Processing Record 30 of Set 9 | lagoa
# Processing Record 31 of Set 9 | feldkirchen
# Processing Record 32 of Set 9 | petropavlovsk-kamchatskiy
# Processing Record 33 of Set 9 | kutahya
# Processing Record 34 of Set 9 | kisangani
# Processing Record 35 of Set 9 | sorong
# Processing Record 36 of Set 9 | asau
# Processing Record 37 of Set 9 | coari
# Processing Record 38 of Set 9 | pacific grove
# Processing Record 39 of Set 9 | vung tau
# Processing Record 40 of Set 9 | mehamn
# Processing Record 41 of Set 9 | lorengau
# Processing Record 42 of Set 9 | falmouth
# Processing Record 43 of Set 9 | benito juarez
# Processing Record 44 of Set 9 | kavieng
# Processing Record 45 of Set 9 | vangaindrano
# Processing Record 46 of Set 9 | ixtapa
# Processing Record 47 of Set 9 | ahuimanu
# Processing Record 48 of Set 9 | pisco
# Processing Record 49 of Set 9 | mpika
# Processing Record 50 of Set 9 | narsingi
# Processing Record 1 of Set 10 | chara
# Processing Record 2 of Set 10 | erdenet
# Processing Record 3 of Set 10 | zelenoborskiy
# Processing Record 4 of Set 10 | black diamond
# Processing Record 5 of Set 10 | chapais
# Processing Record 6 of Set 10 | huarmey
# Processing Record 7 of Set 10 | tripoli
# Processing Record 8 of Set 10 | xalpatlahuac
# Processing Record 9 of Set 10 | vredendal
# Processing Record 10 of Set 10 | concarneau
# Processing Record 11 of Set 10 | mount isa
# Processing Record 12 of Set 10 | esso
# Processing Record 13 of Set 10 | tharrawaddy
# City not found. Skipping...
# Processing Record 14 of Set 10 | bairiki
# Processing Record 15 of Set 10 | vanimo
# Processing Record 16 of Set 10 | tadine
# Processing Record 17 of Set 10 | novaya malykla
# Processing Record 18 of Set 10 | barentsburg
# City not found. Skipping...
# Processing Record 19 of Set 10 | gurupi
# Processing Record 20 of Set 10 | garowe
# Processing Record 21 of Set 10 | matara
# Processing Record 22 of Set 10 | tharad
# Processing Record 23 of Set 10 | anahuac
# Processing Record 24 of Set 10 | san carlos
# Processing Record 25 of Set 10 | ukiah
# Processing Record 26 of Set 10 | santa cruz de la palma
# Processing Record 27 of Set 10 | port blair
# Processing Record 28 of Set 10 | north bend
# Processing Record 29 of Set 10 | bombay
# Processing Record 30 of Set 10 | kununurra
# Processing Record 31 of Set 10 | shimoda
# Processing Record 32 of Set 10 | umm durman
# City not found. Skipping...
# Processing Record 33 of Set 10 | namibe
# Processing Record 34 of Set 10 | jabiru
# City not found. Skipping...
# Processing Record 35 of Set 10 | kuche
# City not found. Skipping...
# Processing Record 36 of Set 10 | aojiang
# Processing Record 37 of Set 10 | lampazos de naranjo
# Processing Record 38 of Set 10 | havre-saint-pierre
# Processing Record 39 of Set 10 | jiwani
# Processing Record 40 of Set 10 | nabire
# Processing Record 41 of Set 10 | matagami
# Processing Record 42 of Set 10 | orange cove
# Processing Record 43 of Set 10 | wasilla
# Processing Record 44 of Set 10 | tres lagoas
# Processing Record 45 of Set 10 | oussouye
# Processing Record 46 of Set 10 | hay river
# Processing Record 47 of Set 10 | gedo
# Processing Record 48 of Set 10 | solnechnyy
# Processing Record 49 of Set 10 | houston
# Processing Record 50 of Set 10 | pietersburg
# Processing Record 1 of Set 11 | sinaloa
# Processing Record 2 of Set 11 | luanda
# Processing Record 3 of Set 11 | konakovo
# Processing Record 4 of Set 11 | ankazoabo
# Processing Record 5 of Set 11 | sakaiminato
# Processing Record 6 of Set 11 | ambilobe
# Processing Record 7 of Set 11 | meulaboh
# Processing Record 8 of Set 11 | hamilton
# Processing Record 9 of Set 11 | victor harbor
# Processing Record 10 of Set 11 | krasnyy oktyabr
# Processing Record 11 of Set 11 | cherdyn
# Processing Record 12 of Set 11 | hambantota
# Processing Record 13 of Set 11 | redmond
# Processing Record 14 of Set 11 | serebryanyy bor
# Processing Record 15 of Set 11 | kamarion
# Processing Record 16 of Set 11 | south lake tahoe
# Processing Record 17 of Set 11 | vysokogornyy
# Processing Record 18 of Set 11 | harstad
# Processing Record 19 of Set 11 | waingapu
# Processing Record 20 of Set 11 | maniitsoq
# Processing Record 21 of Set 11 | bollnas
# Processing Record 22 of Set 11 | taburi
# City not found. Skipping...
# Processing Record 23 of Set 11 | kiunga
# Processing Record 24 of Set 11 | tarhunah
# City not found. Skipping...
# Processing Record 25 of Set 11 | itaituba
# Processing Record 26 of Set 11 | plainview
# Processing Record 27 of Set 11 | bang saphan
# Processing Record 28 of Set 11 | olga
# Processing Record 29 of Set 11 | portobelo
# Processing Record 30 of Set 11 | marv dasht
# City not found. Skipping...
# Processing Record 31 of Set 11 | kalmunai
# Processing Record 32 of Set 11 | san ramon
# Processing Record 33 of Set 11 | gushikawa
# Processing Record 34 of Set 11 | adrar
# Processing Record 35 of Set 11 | olafsvik
# Processing Record 36 of Set 11 | dalbandin
# Processing Record 37 of Set 11 | saint anthony
# Processing Record 38 of Set 11 | ulkan
# Processing Record 39 of Set 11 | yarada
# Processing Record 40 of Set 11 | ouango
# Processing Record 41 of Set 11 | atar
# Processing Record 42 of Set 11 | salamiyah
# Processing Record 43 of Set 11 | kiruna
# Processing Record 44 of Set 11 | nantucket
# Processing Record 45 of Set 11 | aripuana
# Processing Record 46 of Set 11 | baghdad
# Processing Record 47 of Set 11 | povenets
# Processing Record 48 of Set 11 | copiapo
# Processing Record 49 of Set 11 | agadez
# Processing Record 50 of Set 11 | sinnamary
# Processing Record 1 of Set 12 | champerico
# Processing Record 2 of Set 12 | matongo
# Processing Record 3 of Set 12 | chernitsyno
# Processing Record 4 of Set 12 | whitehorse
# Processing Record 5 of Set 12 | gamboula
# Processing Record 6 of Set 12 | chagda
# City not found. Skipping...
# Processing Record 7 of Set 12 | dudinka
# Processing Record 8 of Set 12 | kazachinskoye
# Processing Record 9 of Set 12 | saleaula
# City not found. Skipping...
# Processing Record 10 of Set 12 | coatesville
# Processing Record 11 of Set 12 | tainan
# Processing Record 12 of Set 12 | charlestown
# Processing Record 13 of Set 12 | svetlogorsk
# Processing Record 14 of Set 12 | kokopo
# Processing Record 15 of Set 12 | yamada
# Processing Record 16 of Set 12 | varzea grande
# Processing Record 17 of Set 12 | jiancheng
# Processing Record 18 of Set 12 | port keats
# Processing Record 19 of Set 12 | steinbach
# Processing Record 20 of Set 12 | amnat charoen
# Processing Record 21 of Set 12 | leningradskiy
# Processing Record 22 of Set 12 | xique-xique
# Processing Record 23 of Set 12 | ellisras
# Processing Record 24 of Set 12 | pangnirtung
# Processing Record 25 of Set 12 | tsabong
# Processing Record 26 of Set 12 | palana
# Processing Record 27 of Set 12 | cusuna
# Processing Record 28 of Set 12 | okhotsk
# Processing Record 29 of Set 12 | susehri
# Processing Record 30 of Set 12 | cururupu
# Processing Record 31 of Set 12 | lynn haven
# Processing Record 32 of Set 12 | alausi
# Processing Record 33 of Set 12 | port hardy
# Processing Record 34 of Set 12 | bouca
# Processing Record 35 of Set 12 | atherton
# Processing Record 36 of Set 12 | hokitika
# Processing Record 37 of Set 12 | zyryanovskiy
# City not found. Skipping...
# Processing Record 38 of Set 12 | oudtshoorn
# Processing Record 39 of Set 12 | dargaville
# Processing Record 40 of Set 12 | casper
# Processing Record 41 of Set 12 | arti
# Processing Record 42 of Set 12 | tual
# Processing Record 43 of Set 12 | klaksvik
# Processing Record 44 of Set 12 | doka
# Processing Record 45 of Set 12 | zyryanka
# Processing Record 46 of Set 12 | rawson
# Processing Record 47 of Set 12 | manokwari
# Processing Record 48 of Set 12 | besskorbnaya
# Processing Record 49 of Set 12 | zhigansk
# Processing Record 50 of Set 12 | sorso
# Processing Record 1 of Set 13 | portland
# Processing Record 2 of Set 13 | micheweni
# Processing Record 3 of Set 13 | troitskoye
# Processing Record 4 of Set 13 | fecamp
# Processing Record 5 of Set 13 | honiara
# Processing Record 6 of Set 13 | baruun-urt
# Processing Record 7 of Set 13 | camocim
# Processing Record 8 of Set 13 | higuey
# City not found. Skipping...
# Processing Record 9 of Set 13 | mayskiy
# Processing Record 10 of Set 13 | kurilsk
# Processing Record 11 of Set 13 | bushenyi
# Processing Record 12 of Set 13 | honggang
# Processing Record 13 of Set 13 | gunjur
# Processing Record 14 of Set 13 | oyama
# Processing Record 15 of Set 13 | orange
# Processing Record 16 of Set 13 | el alto
# Processing Record 17 of Set 13 | wajima
# Processing Record 18 of Set 13 | kavaratti
# Processing Record 19 of Set 13 | san juan bautista
# Processing Record 20 of Set 13 | carmen
# Processing Record 21 of Set 13 | port macquarie
# Processing Record 22 of Set 13 | miami
# Processing Record 23 of Set 13 | mahibadhoo
# Processing Record 24 of Set 13 | xianshuigu
# Processing Record 25 of Set 13 | coahuayana
# Processing Record 26 of Set 13 | ahipara
# Processing Record 27 of Set 13 | aswan
# Processing Record 28 of Set 13 | mnogovershinnyy
# Processing Record 29 of Set 13 | brownsville
# Processing Record 30 of Set 13 | paris
# Processing Record 31 of Set 13 | tarudant
# City not found. Skipping...
# Processing Record 32 of Set 13 | cutzamala
# City not found. Skipping...
# Processing Record 33 of Set 13 | ust-omchug
# Processing Record 34 of Set 13 | dongsheng
# Processing Record 35 of Set 13 | niamey
# Processing Record 36 of Set 13 | lewistown
# Processing Record 37 of Set 13 | guymon
# Processing Record 38 of Set 13 | pilar
# Processing Record 39 of Set 13 | morgan city
# Processing Record 40 of Set 13 | umzimvubu
# City not found. Skipping...
# Processing Record 41 of Set 13 | sikonge
# Processing Record 42 of Set 13 | otradnoye
# Processing Record 43 of Set 13 | bemidji
# Processing Record 44 of Set 13 | muli
# Processing Record 45 of Set 13 | maghama
# City not found. Skipping...
# Processing Record 46 of Set 13 | najran
# Processing Record 47 of Set 13 | selikhino
# Processing Record 48 of Set 13 | los llanos de aridane
# Processing Record 49 of Set 13 | nelson bay
# Processing Record 50 of Set 13 | asyut
# Processing Record 1 of Set 14 | cambrils
# Processing Record 2 of Set 14 | galiwinku
# City not found. Skipping...
# Processing Record 3 of Set 14 | sabang
# Processing Record 4 of Set 14 | liwale
# Processing Record 5 of Set 14 | omaruru
# Processing Record 6 of Set 14 | christchurch
# Processing Record 7 of Set 14 | yenagoa
# Processing Record 8 of Set 14 | bantry
# Processing Record 9 of Set 14 | bolshaya chernigovka
# City not found. Skipping...
# Processing Record 10 of Set 14 | salinopolis
# Processing Record 11 of Set 14 | nemuro
# Processing Record 12 of Set 14 | pokrovsk-uralskiy
# City not found. Skipping...
# Processing Record 13 of Set 14 | matadi
# Processing Record 14 of Set 14 | koungou
# Processing Record 15 of Set 14 | dingle
# Processing Record 16 of Set 14 | kasungu
# Processing Record 17 of Set 14 | mayo
# Processing Record 18 of Set 14 | byron bay
# Processing Record 19 of Set 14 | aktau
# Processing Record 20 of Set 14 | maragogi
# Processing Record 21 of Set 14 | sao joao da barra
# Processing Record 22 of Set 14 | maumere
# Processing Record 23 of Set 14 | samarai
# Processing Record 24 of Set 14 | sulangan
# Processing Record 25 of Set 14 | pachperwa
# Processing Record 26 of Set 14 | ancona
# Processing Record 27 of Set 14 | ust-kuyga
# Processing Record 28 of Set 14 | dubki
# Processing Record 29 of Set 14 | am timan
# Processing Record 30 of Set 14 | andenes
# Processing Record 31 of Set 14 | rancho palos verdes
# Processing Record 32 of Set 14 | tubruq
# City not found. Skipping...
# Processing Record 33 of Set 14 | sainte-maxime
# Processing Record 34 of Set 14 | catamarca
# Processing Record 35 of Set 14 | belyy yar
# Processing Record 36 of Set 14 | rock sound
# Processing Record 37 of Set 14 | muroto
# Processing Record 38 of Set 14 | wad rawah
# Processing Record 39 of Set 14 | marcona
# City not found. Skipping...
# Processing Record 40 of Set 14 | grindavik
# Processing Record 41 of Set 14 | sobolevo
# Processing Record 42 of Set 14 | krasnyy chikoy
# Processing Record 43 of Set 14 | karratha
# Processing Record 44 of Set 14 | ngorongoro
# Processing Record 45 of Set 14 | pedernales
# Processing Record 46 of Set 14 | kendari
# Processing Record 47 of Set 14 | buchanan
# Processing Record 48 of Set 14 | borujan
# City not found. Skipping...
# Processing Record 49 of Set 14 | mananjary
# Processing Record 50 of Set 14 | shibarghan
# City not found. Skipping...
# Processing Record 1 of Set 15 | yakshur-bodya
# City not found. Skipping...
# Processing Record 2 of Set 15 | phanom thuan
# Processing Record 3 of Set 15 | oktyabrskiy
# Processing Record 4 of Set 15 | turukhansk
# Processing Record 5 of Set 15 | barranca
# Processing Record 6 of Set 15 | glens falls
# Processing Record 7 of Set 15 | ndele
# Processing Record 8 of Set 15 | acari
# Processing Record 9 of Set 15 | la rochelle
# Processing Record 10 of Set 15 | zyryanskoye
# Processing Record 11 of Set 15 | codrington
# Processing Record 12 of Set 15 | constitucion
# Processing Record 13 of Set 15 | pontianak
# Processing Record 14 of Set 15 | dzhusaly
# City not found. Skipping...
# Processing Record 15 of Set 15 | sao gabriel da cachoeira
# Processing Record 16 of Set 15 | goma
# Processing Record 17 of Set 15 | vilhena
# Processing Record 18 of Set 15 | itarema
# Processing Record 19 of Set 15 | gorontalo
# Processing Record 20 of Set 15 | urla
# Processing Record 21 of Set 15 | plettenberg bay
# Processing Record 22 of Set 15 | riyadh
# Processing Record 23 of Set 15 | opotiki
# Processing Record 24 of Set 15 | quelimane
# Processing Record 25 of Set 15 | haines junction
# Processing Record 26 of Set 15 | kolda
# Processing Record 27 of Set 15 | xining
# Processing Record 28 of Set 15 | pyapon
# Processing Record 29 of Set 15 | flagstaff
# Processing Record 30 of Set 15 | tamiahua
# Processing Record 31 of Set 15 | lensk
# Processing Record 32 of Set 15 | edeia
# Processing Record 33 of Set 15 | agva
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Hithadhoo  -0.6000   73.0833     82.04        74          86
# 1            Hilo  19.7297 -155.0900     81.28        85         100
# 2        Bengkulu  -3.8004  102.2655     85.69        58          58
# 3         Rikitea -23.1203 -134.9692     71.96        77          99
# 4          Atuona  -9.8000 -139.0333     78.30        70           1
# 5         Aklavik  68.2191 -135.0107     43.63        85         100
# 6  Vestmannaeyjar  63.4427  -20.2734     46.27        70          95
# 7       Mahebourg -20.4081   57.7000     75.25        86          20
# 8       Kortkeros  61.8106   51.5806     37.40        81         100
# 9         Dunedin -45.8742  170.5036     51.80        54           7
#
#    Wind Speed Country                 Date
# 0        1.16      MV  2021-09-18 03:23:27
# 1        1.99      US  2021-09-18 03:19:42
# 2        0.96      ID  2021-09-18 03:22:51
# 3       11.25      PF  2021-09-18 03:22:37
# 4       17.05      PF  2021-09-18 03:22:44
# 5        9.40      CA  2021-09-18 03:23:18
# 6        7.29      IS  2021-09-18 03:26:59
# 7        7.07      MU  2021-09-18 03:23:02
# 8        9.75      RU  2021-09-18 03:28:47
# 9       17.00      NZ  2021-09-18 03:21:09

# %%
new_column_order = ["City", "Country", "Date", "Lat", "Lng", "Max Temp",
                    "Humidity", "Cloudiness","Wind Speed"]
city_data_df = city_data_df[new_column_order]

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
